# %%
import matplotlib.pyplot as plt

# %%
yield_Apples=[0.895,0.91,0.919,0.926,0.929,0.931]

# %%
plt.plot(yield_Apples)

# %%
years=[2010,2011,2012,2013,2014,2015]
yield_apples=[0.895,0.91,0.919,0.926,0.929,0.931]
plt.plot(years,yield_apples)

# %%
plt.plot(years,yield_apples)
plt.xlabel('Year')
plt.ylabel('Yield,(tons per hectare)');

# %%
year=range(2000,2008)
apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]

# %%
plt.plot(year,apples)
plt.plot(year,oranges)
plt.xlabel('Year')
plt.ylabel('Yield')
# Out:
# Text(0, 0.5, 'Yield')

# %%
year=range(2000,2008)
apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]
plt.plot(year,apples,marker='o')
plt.plot(year,oranges,marker='x')
plt.xlabel('Year')
plt.ylabel('Yield')
plt.title('Crop yields in Kanto')
plt.legend(['Apples','Oranges']);

# %%
year=range(2000,2008)
apples=[0.895,0.91,0.919,0.926,0.929,0.934,0.936,0.937]
oranges=[0.962,0.941,0.930,0.918,0.908,0.907,0.904,0.901]
plt.plot(year,apples,marker='s',c='b',ls='-',lw=2,ms=8,mew=2,mec='navy')
plt.plot(year,oranges,marker='o',c='r',ls='--',lw=3,ms=10,alpha=0.5)
plt.xlabel('Year')
plt.ylabel('Yield')
plt.title('Crop yields in Kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.plot(year,apples,'s-b')
plt.plot(year,oranges,'o--r')
plt.xlabel('Year')
plt.ylabel('Yield')
plt.title('Crop yields in Kanto')
plt.legend(['Apples','Oranges']);

# %%
plt.plot(year,oranges,'or')
plt.title('yield of oranges')
# Out:
# Text(0.5, 1.0, 'yield of oranges')

# %%
plt.figure(figsize=(6,4))
plt.plot(year,oranges,'or')
plt.title('yield of oranges')
# Out:
# Text(0.5, 1.0, 'yield of oranges')

# %%
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.bar(x,y)
plt.title('Bar chart')
plt.legend(['Bar'])
plt.show()

# %%
x=[3,1,3,12,2,4,4]
y=[3,2,1,4,5,6,7]
plt.scatter(x,y)
plt.title('Scatter plot')
plt.legend(['A'])
plt.xlabel('x')
plt.ylabel('y')
# Out:
# Text(0, 0.5, 'y')

# %%
x=[1,2,3,4]
e=(0.1, 0, 0 ,0)
plt.pie(x,explode =e)
plt.title("PIE CHART")
plt.show()

# %%
import pandas as pd
df= pd.read_csv("/empdata.csv")
df.head()
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000

# %%
df.tail()
# Out:
#    Empid           Ename    Salary         DOJ
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df.head(3)
# Out:
#    Empid   Ename   Salary         DOJ
# 0   1001  Ganesh   1000.0  10-10-2000
# 1   1002    Anil  23000.5   3/20/2002
# 2   1003  Gaurav      NaN  03-03-2002

# %%
df.tail(7)
# Out:
#    Empid           Ename    Salary         DOJ
# 0   1001          Ganesh   1000.00  10-10-2000
# 1   1002            Anil  23000.50   3/20/2002
# 2   1003          Gaurav       NaN  03-03-2002
# 3   1004    Hema Chandra  16500.50  09-10-2000
# 4   1005  Laxmi Prasanna  12000.75  10-08-2000
# 5   1006          Anant    9999.99  09-09-1999

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Empid   6 non-null      int64
#  1   Ename   6 non-null      object
#  2   Salary  5 non-null      float64
#  3   DOJ     6 non-null      object
# dtypes: float64(1), int64(1), object(2)
# memory usage: 320.0+ bytes

# %%
df.describe()
# Out:
#              Empid        Salary
# count     6.000000      5.000000
# mean   1003.500000  12500.348000
# std       1.870829   8139.622234
# min    1001.000000   1000.000000
# 25%    1002.250000   9999.990000
# 50%    1003.500000  12000.750000
# 75%    1004.750000  16500.500000
# max    1006.000000  23000.500000

# %%
df.coloums()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-41-c00e4de84ef8> in <cell line: 1>()
# ----> 1 df.coloums()
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'coloums'

# %%
df['Salary']
# Out:
# 0     1000.00
# 1    23000.50
# 2         NaN
# 3    16500.50
# 4    12000.75
# 5     9999.99
# Name: Salary, dtype: float64

# %%
df[['Empid','Salary']]
# Out:
#    Empid    Salary
# 0   1001   1000.00
# 1   1002  23000.50
# 2   1003       NaN
# 3   1004  16500.50
# 4   1005  12000.75
# 5   1006   9999.99

# %%
df1=df.appends(df)
print('Dimensions of the original frame',df.shape)
print('Dimensions of the frame with duplicates',df1.shape)
df1=df1.drop_duplicates()
print('Dimensions after removing duplicates',df1.shape)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-44-6fc5e6dc85e4> in <cell line: 1>()
# ----> 1 df1=df.appends(df)
#       2 print('Dimensions of the original frame',df.shape)
#       3 print('Dimensions of the frame with duplicates',df1.shape)
#       4 df1=df1.drop_duplicates()
#       5 print('Dimensions after removing duplicates',df1.shape)
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'appends'

# %%
df.dropna(axis=1)
# Out:
#    Empid           Ename         DOJ
# 0   1001          Ganesh  10-10-2000
# 1   1002            Anil   3/20/2002
# 2   1003          Gaurav  03-03-2002
# 3   1004    Hema Chandra  09-10-2000
# 4   1005  Laxmi Prasanna  10-08-2000
# 5   1006          Anant   09-09-1999
